# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
data = pd.read_csv("C://Users//dell//Downloads/loan/loan.csv")

# %%
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# ## Checking the percetange of null values in columns

# %%
data.isnull().mean()*100
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.098195
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %% [markdown]
# ## Dropping the columns having more than 60% of null values

# %%
for value in data[data.columns[data.isnull().mean() > 0.60]]:
    data = data.drop(value, axis=1)

# %% [markdown]
# ## Chekcing the values  having null values in columns

# %%
for value in data[data.columns[data.isnull().mean() > 0.00]]:
    print(value)
# Out:
# emp_title
# emp_length
# desc
# title
# revol_util
# last_pymnt_d
# last_credit_pull_d
# collections_12_mths_ex_med
# chargeoff_within_12_mths
# pub_rec_bankruptcies
# tax_liens

# %%
data.shape
# Out:
# (39717, 54)

# %% [markdown]
# ## There are several columns which doesn't contribute much in the analysis hence it will be fine to remove such columns.
# ### Let's check them

# %%
data = data.drop(['id', 'member_id','emp_title', 'title', 'desc'], axis=1)

# %% [markdown]
# ## Let's check other columns and their values.

# %%
data.nunique()
# Out:
# loan_amnt                       885
# funded_amnt                    1041
# funded_amnt_inv                8205
# term                              2
# int_rate                        371
# installment                   15383
# grade                             7
# sub_grade                        35
# emp_length                       11
# home_ownership                    5
# annual_inc                     5318
# verification_status               3
# issue_d                          55
# loan_status                       3
# pymnt_plan                        1
# url                           39717
# purpose                          14
# zip_code                        823
# addr_state                       50
# dti                            2868
# delinq_2yrs                      11
# earliest_cr_line                526
# inq_last_6mths                    9
# open_acc                         40
# pub_rec                           5
# revol_bal                     21711
# ...

# %% [markdown]
# ### From above we can see there are many columns having single value which doesn't contribute much in the analysis. So will drop such columns

# %%
data = data.drop(['initial_list_status', 'pymnt_plan','initial_list_status', 'collections_12_mths_ex_med','policy_code',
                  'application_type','acc_now_delinq','chargeoff_within_12_mths','delinq_amnt','delinq_2yrs','tax_liens'], axis=1)

# %%
data.shape
# Out:
# (39717, 39)

# %% [markdown]
# ### Let check further columns that do not contribute in the analysis.

# %%
data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           4975.0   36 months   10.65%       162.87
# 1       2500         2500           2500.0   60 months   15.27%        59.83
# 2       2400         2400           2400.0   36 months   15.96%        84.33
# 3      10000        10000          10000.0   36 months   13.49%       339.31
# 4       3000         3000           3000.0   60 months   12.69%        67.79
#
#   grade sub_grade emp_length home_ownership  ...  total_pymnt_inv  \
# 0     B        B2  10+ years           RENT  ...          5833.84
# 1     C        C4   < 1 year           RENT  ...          1008.71
# 2     C        C5  10+ years           RENT  ...          3005.67
# 3     C        C1  10+ years           RENT  ...         12231.89
# 4     B        B5     1 year           RENT  ...          3513.33
#
#   total_rec_prncp total_rec_int total_rec_late_fee recoveries  \
# ...

# %%
data.nunique()
# Out:
# loan_amnt                    885
# funded_amnt                 1041
# funded_amnt_inv             8205
# term                           2
# int_rate                     371
# installment                15383
# grade                          7
# sub_grade                     35
# emp_length                    11
# home_ownership                 5
# annual_inc                  5318
# verification_status            3
# issue_d                       55
# loan_status                    3
# url                        39717
# purpose                       14
# zip_code                     823
# addr_state                    50
# dti                         2868
# earliest_cr_line             526
# inq_last_6mths                 9
# open_acc                      40
# pub_rec                        5
# revol_bal                  21711
# revol_util                  1089
# total_acc                     82
# out_prncp                   1137
# out_prncp_inv               1138
# ...

# %% [markdown]
# ### There are a few more columns which doesn't contribute in analysis so let's remove them too.

# %%
data = data.drop(['funded_amnt', 'url', 'zip_code', 'last_credit_pull_d', 'addr_state', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
       'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int','total_rec_late_fee', 'recoveries'], axis=1)

# %%
data.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0       5000           4975.0   36 months   10.65%       162.87     B
# 1       2500           2500.0   60 months   15.27%        59.83     C
# 2       2400           2400.0   36 months   15.96%        84.33     C
# 3      10000          10000.0   36 months   13.49%       339.31     C
# 4       3000           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc  ... inq_last_6mths  \
# 0        B2  10+ years           RENT     24000.0  ...              1
# 1        C4   < 1 year           RENT     30000.0  ...              5
# 2        C5  10+ years           RENT     12252.0  ...              2
# 3        C1  10+ years           RENT     49200.0  ...              1
# 4        B5     1 year           RENT     80000.0  ...              0
#
#   open_acc pub_rec revol_bal  revol_util total_acc  collection_recovery_fee  \
# ...

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
#        'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'dti',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
data = data.drop([ 'collection_recovery_fee','last_pymnt_d', 'last_pymnt_amnt', 'pub_rec_bankruptcies'], axis=1)

# %%
data.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0       5000           4975.0   36 months   10.65%       162.87     B
# 1       2500           2500.0   60 months   15.27%        59.83     C
# 2       2400           2400.0   36 months   15.96%        84.33     C
# 3      10000          10000.0   36 months   13.49%       339.31     C
# 4       3000           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc  ...  loan_status  \
# 0        B2  10+ years           RENT     24000.0  ...   Fully Paid
# 1        C4   < 1 year           RENT     30000.0  ...  Charged Off
# 2        C5  10+ years           RENT     12252.0  ...   Fully Paid
# 3        C1  10+ years           RENT     49200.0  ...   Fully Paid
# 4        B5     1 year           RENT     80000.0  ...      Current
#
#           purpose    dti earliest_cr_line  inq_last_6mths open_acc  pub_rec  \
# ...

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
#        'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'dti',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc'],
#       dtype='object')

# %%
data.shape
# Out:
# (39717, 22)

# %%
data = data.drop('revol_bal', axis=1)

# %%
data.shape
# Out:
# (39717, 21)

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
#        'grade', 'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'dti',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_util', 'total_acc'],
#       dtype='object')

# %%
 data.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0       5000           4975.0   36 months   10.65%       162.87     B
# 1       2500           2500.0   60 months   15.27%        59.83     C
# 2       2400           2400.0   36 months   15.96%        84.33     C
# 3      10000          10000.0   36 months   13.49%       339.31     C
# 4       3000           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc  ... issue_d  loan_status  \
# 0        B2  10+ years           RENT     24000.0  ...  Dec-11   Fully Paid
# 1        C4   < 1 year           RENT     30000.0  ...  Dec-11  Charged Off
# 2        C5  10+ years           RENT     12252.0  ...  Dec-11   Fully Paid
# 3        C1  10+ years           RENT     49200.0  ...  Dec-11   Fully Paid
# 4        B5     1 year           RENT     80000.0  ...  Dec-11      Current
#
#           purpose    dti  earliest_cr_line inq_last_6mths  open_acc  pub_rec  \
# ...

# %% [markdown]
# ### Our aim here to find the people who can default hence we can limit the data which will not contribute much in the analysis like the people who have already availed the loan and they are still paying their installment. So Let's limit the data by removing such people.¶

# %%
data = data[data.loan_status != "Current"]

# %%
data.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0       5000           4975.0   36 months   10.65%       162.87     B
# 1       2500           2500.0   60 months   15.27%        59.83     C
# 2       2400           2400.0   36 months   15.96%        84.33     C
# 3      10000          10000.0   36 months   13.49%       339.31     C
# 5       5000           5000.0   36 months    7.90%       156.46     A
#
#   sub_grade emp_length home_ownership  annual_inc  ... issue_d  loan_status  \
# 0        B2  10+ years           RENT     24000.0  ...  Dec-11   Fully Paid
# 1        C4   < 1 year           RENT     30000.0  ...  Dec-11  Charged Off
# 2        C5  10+ years           RENT     12252.0  ...  Dec-11   Fully Paid
# 3        C1  10+ years           RENT     49200.0  ...  Dec-11   Fully Paid
# 5        A4    3 years           RENT     36000.0  ...  Dec-11   Fully Paid
#
#           purpose    dti  earliest_cr_line inq_last_6mths  open_acc  pub_rec  \
# ...
